# %% [markdown]
# # Module II: Enhancing Geospatial Insight with Map Visualization
#
# **Objective:** This notebook introduces Folium, a Python library that makes it
# easy to visualize data on an interactive Leaflet map. We will cover:
# - Creating basic interactive maps.
# - Plotting point data (e.g., city locations).
# - Creating choropleth maps (e.g., regional statistics).
#
# **Libraries to be used:** pandas, Folium

# %%
#-------------------------------------------------------------------------------
# 2. SETUP (Code Cell)
#-------------------------------------------------------------------------------
import pandas as pd
import folium

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %% [markdown]
# ## 3.1 Introduction to Folium
# Folium builds on the data wrangling strengths of Python and the mapping
# strengths of Leaflet.js. It enables you to create interactive maps that can be
# embedded in Jupyter notebooks or saved as HTML files.

# %%
#-------------------------------------------------------------------------------
# 3.2 Creating a Base Map (Code Cell)
#-------------------------------------------------------------------------------
# Create a map centered around a general location, e.g., Europe
map_base = folium.Map(location=[1, 2], zoom_start=4)
print("Base map created. Displaying map (renders directly in Jupyter):")
map_base # Display the map

# --- Showing different tiles ---
"""
**Different Tile Layers:**
Folium supports various tile layers. Common ones include:
- 'OpenStreetMap' (default)
- 'CartoDB positron' / 'CartoDB dark_matter'
- 'Stamen Terrain', 'Stamen Toner', 'Stamen Watercolor'
"""
map_tiles_example = folium.Map(location=[40.7128, -74.0060], zoom_start=10, tiles='CartoDB positron')
folium.Marker(
    location=[40.7128, -74.0060],
    popup='New York City',
    tooltip='Click for NYC!'
).add_to(map_tiles_example)
print("\nMap with 'CartoDB positron' tiles:")
map_tiles_example
# Out:
# Base map created. Displaying map (renders directly in Jupyter):
#
# Map with 'CartoDB positron' tiles:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_af2354ad66378544d2535a6ae31a8c19 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_af2354ad66378544d2535a6ae31a8c19&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_af2354ad66378544d2535a6ae31a8c19 = L.map(
#                 &quot;map_af2354ad66378544d2535a6ae31a8c19&quot;,
#                 {
#                     center: [40.7128, -74.006],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9b1712d03f38cd4d76e1ce447b7a0a0e = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9b1712d03f38cd4d76e1ce447b7a0a0e.addTo(map_af2354ad66378544d2535a6ae31a8c19);
#
#
#             var marker_87dd20c4e6fcddbaa12acb4ceb883e87 = L.marker(
#                 [40.7128, -74.006],
#                 {
# }
#             ).addTo(map_af2354ad66378544d2535a6ae31a8c19);
#
#
#         var popup_62d2f07ffdf746f0e697c9b725088cfb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c794ab36f4fa9a2e381a28ba2d4aae5a = $(`&lt;div id=&quot;html_c794ab36f4fa9a2e381a28ba2d4aae5a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;New York City&lt;/div&gt;`)[0];
#                 popup_62d2f07ffdf746f0e697c9b725088cfb.setContent(html_c794ab36f4fa9a2e381a28ba2d4aae5a);
#
#
#
#         marker_87dd20c4e6fcddbaa12acb4ceb883e87.bindPopup(popup_62d2f07ffdf746f0e697c9b725088cfb)
#         ;
#
#
#
#
#             marker_87dd20c4e6fcddbaa12acb4ceb883e87.bindTooltip(
#                 `&lt;div&gt;
#                      Click for NYC!
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 4.1 Plotting Markers for Point Data
# We can add markers to a map to represent specific locations, such as cities,
# research sites, or event occurrences.

# %%
#-------------------------------------------------------------------------------
# 4.2 Hands-on: Plotting World Cities (Code Cells)
#-------------------------------------------------------------------------------
# --- 4.2.1 Load City Data ---
cities_df = pd.read_csv('worldcities.csv')
print("Sample cities data:")
print(cities_df)
# Out:
# Sample cities data:
#           city city_ascii      lat       lon       country iso2 iso3  \
# 0        Tokyo      Tokyo  35.6870  139.7495         Japan   JP  JPN
# 1      Jakarta    Jakarta  -6.1750  106.8275     Indonesia   ID  IDN
# 2        Delhi      Delhi  28.6100   77.2300         India   IN  IND
# 3    Guangzhou  Guangzhou  23.1300  113.2600         China   CN  CHN
# 4       Mumbai     Mumbai  19.0761   72.8775         India   IN  IND
# ..         ...        ...      ...       ...           ...  ...  ...
# 994    Yanggok    Yanggok  37.6333  127.2167  Korea, South   KR  KOR
# 995    Zhongba    Zhongba  31.7710  104.7550         China   CN  CHN
# 996     Osogbo     Osogbo   7.7667    4.5667       Nigeria   NG  NGA
# 997     Sizhan     Sizhan  38.9846  106.3828         China   CN  CHN
# 998      Suohe      Suohe  34.7833  113.3500         China   CN  CHN
#
#       admin_name  capital  population          id
# 0          Tōkyō  primary    37785000  1392685764
# 1        Jakarta  primary    33756000  1360771077
# 2          Delhi    admin    32226000  1356872604
# 3      Guangdong    admin    26940000  1156237133
# 4    Mahārāshtra    admin    24973000  1356226629
# ..           ...      ...         ...         ...
# 994     Gyeonggi      NaN      732376  1410188674
# 995      Sichuan    minor      731343  1156515985
# 996         Osun    admin      731000  1566395088
# 997      Ningxia      NaN      730400  1156450911
# 998        Henan    minor      730135  1156236948
#
# [999 rows x 11 columns]

# %%
# --- 4.2.2 Create Map and Add Markers ---
map_cities = folium.Map(location=[cities_df['lat'].mean(), cities_df['lon'].mean()], zoom_start=2)

for index, row in cities_df.iterrows():
    folium.Marker(
        location=[row['lat'], row['lon']],
        popup=f"{row['city']}<br>Population: {row['population']:,}", # Formatted popup
        tooltip=row['city'],
        icon=folium.Icon(color='blue', icon='info-sign') # Example custom icon
    ).add_to(map_cities)

print("\nMap with city markers:")
map_cities
# Out:
# Map with city markers:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f5a2301f414ccdf646f92c2275f9e734 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f5a2301f414ccdf646f92c2275f9e734&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f5a2301f414ccdf646f92c2275f9e734 = L.map(
#                 &quot;map_f5a2301f414ccdf646f92c2275f9e734&quot;,
#                 {
#                     center: [25.78003913913914, 58.56128998998999],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fb462e53a680396ba20261a43593b084 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fb462e53a680396ba20261a43593b084.addTo(map_f5a2301f414ccdf646f92c2275f9e734);
#
#
#             var marker_54ec7c72bed9dae81dc789e6bd9edd7f = L.marker(
#                 [35.687, 139.7495],
#                 {
# }
#             ).addTo(map_f5a2301f414ccdf646f92c2275f9e734);
#
#
#             var icon_6a9a4080f053c360c1847c3843f48548 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_dca9f3d93fc5c0b3678107e588269480 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_52088b62774edf10bd123a4ef98897fc = $(`&lt;div id=&quot;html_52088b62774edf10bd123a4ef98897fc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tokyo&lt;br&gt;Population: 37,785,000&lt;/div&gt;`)[0];
#                 popup_dca9f3d93fc5c0b3678107e588269480.setContent(html_52088b62774edf10bd123a4ef98897fc);
#
#
#
#         marker_54ec7c72bed9dae81dc789e6bd9edd7f.bindPopup(popup_dca9f3d93fc5c0b3678107e588269480)
#         ;
#
#
#
#
#             marker_54ec7c72bed9dae81dc789e6bd9edd7f.bindTooltip(
#                 `&lt;div&gt;
#                      Tokyo
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_54ec7c72bed9dae81dc789e6bd9edd7f.setIcon(icon_6a9a4080f053c360c1847c3843f48548);
#
#
#             var marker_a1ab83a99ddf653429e8fed92e282a5a = L.marker(
#                 [-6.175, 106.8275],
#                 {
# }
#             ).addTo(map_f5a2301f414ccdf646f92c2275f9e734);
#
#
#             var icon_70d39194533381f0ee2fff003f05ba15 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_56567e7bdf25f7e8eb11c5c28428bb8e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_52310a65b6de37be1eeca762f3400332 = $(`&lt;div id=&quot;html_52310a65b6de37be1eeca762f3400332&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Jakarta&lt;br&gt;Population: 33,756,000&lt;/div&gt;`)[0];
#                 popup_56567e7bdf25f7e8eb11c5c28428bb8e.setContent(html_52310a65b6de37be1eeca762f3400332);
#
#
#
#         marker_a1ab83a99ddf653429e8fed92e282a5a.bindPopup(popup_56567e7bdf25f7e8eb11c5c28428bb8e)
#         ;
#
#
#
#
#             marker_a1ab83a99ddf653429e8fed92e282a5a.bindTooltip(
#                 `&lt;div&gt;
#                      Jakarta
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_a1ab83a99ddf653429e8fed92e282a5a.setIcon(icon_70d39194533381f0ee2fff003f05ba15);
#
#
#             var marker_5da97d14bd3b26f28b2e2f3f4bf00ee7 = L.marker(
#                 [28.61, 77.23],
#                 {
# }
#             ).addTo(map_f5a2301f414ccdf646f92c2275f9e734);
#
#
#             var icon_6f6c270b46f833557bd63d322f0a1014 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_7d1a09c8d4cee62f468c7f1e223b934f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8f90c068ffd00338b536fd2340e84f98 = $(`&lt;div id=&quot;html_8f90c068ffd00338b536fd2340e84f98&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Delhi&lt;br&gt;Population: 32,226,000&lt;/div&gt;`)[0];
#                 popup_7d1a09c8d4cee62f468c7f1e223b934f.setContent(html_8f90c068ffd00338b536fd2340e84f98);

# %% [markdown]
# ## 5.1 Creating Choropleth Maps
# Choropleth maps use color intensity to represent data values across
# predefined geographical regions (e.g., countries, states, counties).
# You typically need:
# 1. A GeoJSON/TopoJSON file defining the boundaries of your regions.
# 2. A dataset (e.g., Pandas DataFrame) with values for those regions.

# %%
#-------------------------------------------------------------------------------
# 5.2 Hands-on: US States Population (Example) (Code Cells)
#-------------------------------------------------------------------------------
# --- 5.2.1 Prepare Data ---
# GeoJSON for US States (often available online, e.g., from Folium examples or public sources)
# For a workshop, it's best to provide a direct link or a local file.
# Example: A common US States GeoJSON URL (ensure it's accessible)
# us_states_geojson_url = "https://raw.githubusercontent.com/python-visualization/folium/main/examples/data/us-states.json"
# Or, using a well-known TopoJSON like us-10m.v1.json mentioned in the report [23]
# (This might require conversion or specific handling if it's TopoJSON)
# For simplicity, let's assume a GeoJSON file `us-states.json` is in the same directory or provide a direct URL.
# If using a local file: us_states_geojson_path = 'us-states.json'
# Make sure this file exists or adjust the path.
# For this notebook, we'll use a known public URL for us-states.json
us_states_geojson_url = "us_states.json"
# Check if this URL is still valid or replace with a reliable one.
# The one from Folium examples is: "https://raw.githubusercontent.com/python-visualization/folium/main/examples/data/us-states.json"

unemployment_df = pd.read_csv('us_unemployment_oct_2012.csv')
print("US States unemployment data:")
print(unemployment_df)
# Out:
# US States unemployment data:
#    State  Unemployment
# 0     AL           7.1
# 1     AK           6.8
# 2     AZ           8.1
# 3     AR           7.2
# 4     CA          10.1
# 5     CO           7.7
# 6     CT           8.4
# 7     DE           7.1
# 8     FL           8.2
# 9     GA           8.8
# 10    HI           5.4
# 11    ID           6.6
# 12    IL           8.8
# 13    IN           8.4
# 14    IA           5.1
# 15    KS           5.6
# 16    KY           8.1
# 17    LA           5.9
# 18    ME           7.2
# 19    MD           6.8
# 20    MA           6.7
# 21    MI           9.1
# 22    MN           5.6
# 23    MS           9.1
# 24    MO           6.7
# 25    MT           5.8
# 26    NE           3.9
# 27    NV          10.3
# 28    NH           5.7
# 29    NJ           9.6
# 30    NM           6.8
# 31    NY           8.4
# 32    NC           9.4
# 33    ND           3.2
# 34    OH           6.9
# 35    OK           5.2
# 36    OR           8.5
# 37    PA           8.0
# 38    RI          10.1
# 39    SC           8.8
# 40    SD           4.4
# 41    TN           7.8
# 42    TX           6.4
# 43    UT           5.5
# 44    VT           5.0
# 45    VA           5.8
# 46    WA           7.8
# 47    WV           7.5
# 48    WI           6.8
# 49    WY           5.1

# %%
# --- 5.2.2 Create Choropleth Map ---
# Create a base map centered on the US
map_choropleth = folium.Map(location=[43, -100], zoom_start=4)

# Add the Choropleth layer
# The `key_on` parameter needs to match the property in your GeoJSON that identifies the states.
# Common ones are 'feature.id' or 'feature.properties.name' or 'feature.properties.STUSPS'
# You might need to inspect your GeoJSON file to find the correct key.
# For the example us-states.json from folium, 'feature.id' often works for 2-letter state codes.
try:
    folium.Choropleth(
        geo_data='us_states.json', # Path or URL to GeoJSON
        name='choropleth',
        data=unemployment_df,
        columns=['State', 'Unemployment'], # DataFrame columns: 1st for key, 2nd for value
        key_on='feature.id',      # Path to the field in GeoJSON to bind data on (e.g., 'feature.id' or 'feature.properties.name')
        fill_color='YlGnBu',      # Color scheme (e.g., 'YlGn', 'PuRd', 'BuPu')
        fill_opacity=0.7,
        line_opacity=0.2,
        legend_name='Unemployment by State',
        highlight=True # Highlight feature on mouseover
    ).add_to(map_choropleth)

    folium.LayerControl().add_to(map_choropleth) # If you have multiple layers

    print("\nChoropleth map created. Displaying map:")
    display(map_choropleth)
except Exception as e:
    print(f"\nCould not create choropleth map. Error: {e}")
    print("Please ensure the GeoJSON URL is correct and accessible, and the `key_on` parameter matches your GeoJSON structure.")
    print("The `key_on` for the Folium example 'us-states.json' is typically 'feature.id' for 2-letter state codes.")
# Out:
# Choropleth map created. Displaying map:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ec4d830776a71d10d5c8a5cdbdf96b9a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ec4d830776a71d10d5c8a5cdbdf96b9a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ec4d830776a71d10d5c8a5cdbdf96b9a = L.map(
#                 &quot;map_ec4d830776a71d10d5c8a5cdbdf96b9a&quot;,
#                 {
#                     center: [43.0, -100.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2864b076de8bc125d0abfee0e5915e8c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2864b076de8bc125d0abfee0e5915e8c.addTo(map_ec4d830776a71d10d5c8a5cdbdf96b9a);
#
#
#             var choropleth_bf68b7464f493bd9bfd2280b58c7b381 = L.featureGroup(
#                 {
# }
#             );
#
#
#         function geo_json_2d26b7905a1fa6f980c661843cabad7d_styler(feature) {
#             switch(feature.id) {
#                 case &quot;AL&quot;: case &quot;AK&quot;: case &quot;AR&quot;: case &quot;CO&quot;: case &quot;DE&quot;: case &quot;ME&quot;: case &quot;MD&quot;: case &quot;NM&quot;: case &quot;OH&quot;: case &quot;TN&quot;: case &quot;WA&quot;: case &quot;WV&quot;: case &quot;WI&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#41b6c4&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;AZ&quot;: case &quot;CT&quot;: case &quot;FL&quot;: case &quot;GA&quot;: case &quot;IL&quot;: case &quot;IN&quot;: case &quot;KY&quot;: case &quot;MI&quot;: case &quot;MS&quot;: case &quot;NY&quot;: case &quot;OR&quot;: case &quot;PA&quot;: case &quot;SC&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#2c7fb8&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;CA&quot;: case &quot;NV&quot;: case &quot;NJ&quot;: case &quot;NC&quot;: case &quot;RI&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#253494&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;HI&quot;: case &quot;IA&quot;: case &quot;OK&quot;: case &quot;SD&quot;: case &quot;UT&quot;: case &quot;VT&quot;: case &quot;WY&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#c7e9b4&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;ID&quot;: case &quot;KS&quot;: case &quot;LA&quot;: case &quot;MA&quot;: case &quot;MN&quot;: case &quot;MO&quot;: case &quot;MT&quot;: case &quot;NH&quot;: case &quot;TX&quot;: case &quot;VA&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#7fcdbb&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffcc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#             }
#         }
#         function geo_json_2d26b7905a1fa6f980c661843cabad7d_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.8999999999999999, &quot;weight&quot;: 3};
#             }
#         }
#
#         function geo_json_2d26b7905a1fa6f980c661843cabad7d_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_2d26b7905a1fa6f980c661843cabad7d.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_2d26b7905a1fa6f980c661843cabad7d_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_2d26b7905a1fa6f980c661843cabad7d = L.geoJson(null, {
#                 onEachFeature: geo_json_2d26b7905a1fa6f980c661843cabad7d_onEachFeature,
#
#                 style: geo_json_2d26b7905a1fa6f980c661843cabad7d_styler,
#             ...{
# }
#         });
#
#         function geo_json_2d26b7905a1fa6f980c661843cabad7d_add (data) {
#             geo_json_2d26b7905a1fa6f980c661843cabad7d
#                 .addData(data);
#         }
#             geo_json_2d26b7905a1fa6f980c661843cabad7d_add({&q

# %% [markdown]
# ## 6. Applications
#
# Geospatial visualizations are powerful for:
# - **Research:**
#     - Mapping study sites, sample locations, or species distributions.
#     - Visualizing demographic data, election results, or public health patterns.
#     - Analyzing spatial trends and disparities.
# - **Teaching:**
#     - Bringing geography, history, and social studies to life.
#     - Illustrating environmental changes or historical migrations.
#     - Creating interactive learning tools for students to explore spatial data.
#
# (Refer to Section V.C of the main training document for more ideas)

# %% [markdown]
# ## 7. Module II Conclusion
#
# You've learned the basics of creating interactive maps with Folium, including
# plotting point data and generating choropleth maps. These skills are invaluable
# for any work involving geographically referenced data.
